# %%
import requests
import os
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urlencode

# %%
# Send a GET request to the Audubon bird guide website
url = "https://www.audubon.org/bird-guide"
response = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Find the specific section containing the bird names
# For example, if the bird names are in a div with class "bird-names-section", you would do:
bird_section = soup.find('div', class_='birdguide-search-results')

# Extract bird names from the section
bird_names = [name.text.strip() for name in bird_section.find_all('span', class_='bird-card-title')]

# Create a dataframe
df = pd.DataFrame({'Bird Names': bird_names})

# Display the dataframe
print(df)
# Out:
#                     Bird Names
# 0            Northern Cardinal
# 1                   Barred Owl
# 2                     Blue Jay
# 3              Red-tailed Hawk
# 4             Great Horned Owl
# ..                         ...
# 828  Wedge-rumped Storm-petrel
# 829            Murphy's Petrel
# 830              Thayer's Gull
# 831    Iceland Gull (Thayer's)
# 832          Western Scrub-Jay
#
# [833 rows x 1 columns]

# %%
df.tail(10)
# Out:
#                     Bird Names
# 823        Siberian Rubythroat
# 824         Olive-backed Pipit
# 825         Piratic Flycatcher
# 826             Mottled Petrel
# 827              Pechora Pipit
# 828  Wedge-rumped Storm-petrel
# 829            Murphy's Petrel
# 830              Thayer's Gull
# 831    Iceland Gull (Thayer's)
# 832          Western Scrub-Jay

# %%
def format_bird_name(bird_name):
    # Remove parenthesis and content within them
    if "(" in bird_name:
        bird_name = bird_name.split("(")[0]
    
    # Split on slash and take the name to the right
    if "/" in bird_name:
        bird_name = bird_name.split("/")[-1]
    
    # Add hyphen between words
    formatted_name = "-".join(bird_name.split())
    
    # Convert to lowercase
    formatted_name = formatted_name.lower()
    
    # Remove apostrophes
    formatted_name = formatted_name.replace("'", "")
    
    return formatted_name.strip()  # Strip any leading/trailing spaces

# Apply the formatting function to each row of the dataframe
df_formatted_names = df.apply(lambda row: format_bird_name(row['Bird Names']), axis=1)

# Create a new dataframe with the formatted names
df_formatted = pd.DataFrame({'Formatted Names': df_formatted_names})

print(df_formatted)
# Out:
#                Formatted Names
# 0            northern-cardinal
# 1                   barred-owl
# 2                     blue-jay
# 3              red-tailed-hawk
# 4             great-horned-owl
# ..                         ...
# 828  wedge-rumped-storm-petrel
# 829             murphys-petrel
# 830               thayers-gull
# 831               iceland-gull
# 832          western-scrub-jay
#
# [833 rows x 1 columns]

# %%
df_formatted.head(10)
# Out:
#      Formatted Names
# 0  northern-cardinal
# 1         barred-owl
# 2           blue-jay
# 3    red-tailed-hawk
# 4   great-horned-owl
# 5        house-finch
# 6       gray-catbird
# 7      mourning-dove
# 8      american-crow
# 9     american-robin

# %%
rawbirdata= pd.DataFrame(index = range(839), columns=["name", "sciname", "webname", "at_glance", "category", "conservation", "habitat", "region", "behavior", "population", "range_image", "description", "size", "color", "wing_shape", "tail_shape", "call_pattern", "call_type", "calls_audio", "habitat_ext", "eggs", "young", "feeding_behavior", "diet", "nesting", "images"])

base_url = "https://www.audubon.org/field-guide/bird/"

# %%
rawbirdata["webname"] = df_formatted["Formatted Names"]
for index, row in rawbirdata.iterrows():
    rawbirdata.at[index, 'images'] = []
    rawbirdata.at[index, 'calls_audio'] = {}
rawbirdata.head(5)
# Out:
#   name sciname            webname at_glance category conservation habitat  \
# 0  NaN     NaN  northern-cardinal       NaN      NaN          NaN     NaN
# 1  NaN     NaN         barred-owl       NaN      NaN          NaN     NaN
# 2  NaN     NaN           blue-jay       NaN      NaN          NaN     NaN
# 3  NaN     NaN    red-tailed-hawk       NaN      NaN          NaN     NaN
# 4  NaN     NaN   great-horned-owl       NaN      NaN          NaN     NaN
#
#   region behavior population  ... call_pattern call_type calls_audio  \
# 0    NaN      NaN        NaN  ...          NaN       NaN          {}
# 1    NaN      NaN        NaN  ...          NaN       NaN          {}
# 2    NaN      NaN        NaN  ...          NaN       NaN          {}
# 3    NaN      NaN        NaN  ...          NaN       NaN          {}
# 4    NaN      NaN        NaN  ...          NaN       NaN          {}
#
#   habitat_ext eggs young feeding_behavior diet nesting images
# 0         NaN  NaN   NaN              NaN  NaN     NaN     []
# 1         NaN  NaN   NaN              NaN  NaN     NaN     []
# 2         NaN  NaN   NaN              NaN  NaN     NaN     []
# 3         NaN  NaN   NaN              NaN  NaN     NaN     []
# 4         NaN  NaN   NaN              NaN  NaN     NaN     []
#
# [5 rows x 26 columns]

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys  
from selenium.webdriver.chrome.options import Options  
import time

# %%
def getRange (urly):
    chrome_options = Options()
    driver = webdriver.Chrome(options=chrome_options)

    # Specify the URL
    URL = urly

    # Open the URL in the browser
    driver.get(URL)

    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    time.sleep(5)

    # Get the page source
    HTML = driver.page_source

    # Close the browser
    driver.quit()

    # Parse the HTML using Beautiful Soup
    soup = BeautifulSoup(HTML, 'html.parser')

    # Find the <div> element with class "bird-rangemap"
    rangemap_div = soup.find('div', class_='bird_info_item info_migration').find('div', class_='bird-rangemap').find('source')['data-srcset']

    # Print the found element
    return rangemap_div

# %%
def getSounds (urly):
    chrome_options = Options()
    driver = webdriver.Chrome(options=chrome_options)


    # Specify the URL
    URL = urly

    # Open the URL in the browser
    driver.get(URL)

    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    time.sleep(5)

    # Get the page source
    HTML = driver.page_source

    # Close the browser
    driver.quit()

    # Parse the HTML using Beautiful Soup
    soup = BeautifulSoup(HTML, 'html.parser')

    soundivs = soup.find('div', id='info_sounds').find('div', class_='bird-songs-calls').find_all('figure', class_='track')

    dicBird = {}

    for soundiv in soundivs:
        keyRaw = soundiv.find('figcaption')
        key = keyRaw.get_text(strip=True)
        value = soundiv.find('audio')['data-src']
        dicBird[key] = value


    return dicBird

# %%
for index, bird in rawbirdata.iterrows():

    bird_url = base_url + bird["webname"]
    response = requests.get(bird_url)
    soup = BeautifulSoup(response.content, "html.parser")
  
    #CALL AUDIOS
    rawbirdata.at[index, 'calls_audio'] = getSounds(bird_url)

    #RANGE IMAGE
    rawbirdata.at[index, 'range_image'] = getRange(bird_url)

    #BIRD IMAGES
    medias = soup.find_all("div", class_="media-data")
    for media in medias:
        sources = media.find_all("source")
        if sources and sources[0].has_attr('srcset'):
            link_name = sources[0]['srcset']  
        elif sources:
            link_name = sources[0]['data-srcset']  
        else:
            link_name = None 
        current_list = rawbirdata.at[index, 'images']
        current_list.append(link_name)
        rawbirdata.at[index, 'images'] = current_list

  
    #COMMON NAME
    cont_name = soup.find("div", class_="bird-navigation-rail related_arts_present").find("div", class_="bird-meta").find("div", class_="bird-title")
    para_name = cont_name.get_text(strip=True)
    rawbirdata.at[index, "name"] = para_name

    #SCIENTIFIC NAME        
    cont_sciname = soup.find("div", class_="bird-navigation-rail related_arts_present").find("div", class_="bird-meta").find("div", class_="subtitle")
    para_sciname = cont_sciname.get_text(strip=True)
    rawbirdata.at[index, "sciname"] = para_sciname

    #AT A GLANCE
    cont_glance = soup.find("div", class_="content_part").find("div", class_="intro_part").find("div", class_="intro_grid bird_page_grid_4x5").find("div", class_="intro_text")
    para_glance = cont_glance.get_text(strip=True)
    rawbirdata.at[index, "at_glance"] = para_glance

    #CATEGORY
    if soup.find("div", class_="bird-taxonomy grid_type").find("div", class_="tax-item icons_dictionary_before layers_icon") != None:
        cont_cat = soup.find("div", class_="bird-taxonomy grid_type").find("div", class_="tax-item icons_dictionary_before layers_icon").find("div", class_="tax-value")
        para_cat = cont_cat.get_text(strip=True)
        rawbirdata.at[index, "category"] = para_cat

    #CONSERVATION
    if soup.find("div", class_="bird-taxonomy grid_type").find("div", class_="tax-item icons_dictionary_before shield_icon") != None:
        cont_cons = soup.find("div", class_="bird-taxonomy grid_type").find("div", class_="tax-item icons_dictionary_before shield_icon").find("div", class_="tax-value")
        para_cons = cont_cons.get_text(strip=True)
        rawbirdata.at[index, "conservation"] = para_cons

    #HABITAT (SMALL)
    if soup.find("div", class_="bird-taxonomy grid_type").find("div", class_="tax-item icons_dictionary_before home_icon") != None:    
        cont_hab = soup.find("div", class_="bird-taxonomy grid_type").find("div", class_="tax-item icons_dictionary_before home_icon").find("div", class_="tax-value")
        para_hab = cont_hab.get_text(strip=True)
        rawbirdata.at[index, "habitat"] = para_hab

    #REGION
    if soup.find("div", class_="bird-taxonomy grid_type").find("div", class_="tax-item icons_dictionary_before map_icon") != None:
        cont_reg = soup.find("div", class_="bird-taxonomy grid_type").find("div", class_="tax-item icons_dictionary_before map_icon").find("div", class_="tax-value")
        para_reg = cont_reg.get_text(strip=True)
        rawbirdata.at[index, "region"] = para_reg

    #BEHAVIOR
    if soup.find("div", class_="bird-taxonomy grid_type").find("div", class_="tax-item icons_dictionary_before bird_icon") != None:
        cont_beh = soup.find("div", class_="bird-taxonomy grid_type").find("div", class_="tax-item icons_dictionary_before bird_icon").find("div", class_="tax-value")
        para_beh = cont_beh.get_text(strip=True)
        rawbirdata.at[index, "behavior"] = para_beh

    #POPULATION
    if soup.find("div", class_="bird-taxonomy grid_type").find("div", class_="tax-item icons_dictionary_before flock_icon") != None:
        cont_pop = soup.find("div", class_="bird-taxonomy grid_type").find("div", class_="tax-item icons_dictionary_before flock_icon").find("div", class_="tax-value")
        para_pop = cont_pop.get_text(strip=True)
        rawbirdata.at[index, "population"] = para_pop


    



    #CALL PATTERN, CALL TYPE, SIZE, COLOR, WING SHAPE, TAIL SHAPE
    tax_inlines = soup.find_all("div", class_="bird-taxonomy inline_type")
    for type in tax_inlines:
        if soup.find("div", class_="tax-item icons_dictionary_before advocacy_icon") != None:
            cont_callpat = soup.find("div", class_="tax-item icons_dictionary_before advocacy_icon").find("div", class_="tax-value")
            para_callpat = cont_callpat.get_text(strip=True)
            rawbirdata.at[index, "call_pattern"] = para_callpat

        if soup.find("div", class_="tax-item icons_dictionary_before loudspeaker_icon") != None:
            cont_calltyp = soup.find("div", class_="tax-item icons_dictionary_before loudspeaker_icon").find("div", class_="tax-value")
            para_calltyp = cont_calltyp.get_text(strip=True)
            rawbirdata.at[index, "call_type"] = para_calltyp
        
        if soup.find("div", class_="tax-item icons_dictionary_before size_icon") != None:
            cont_size = soup.find("div", class_="tax-item icons_dictionary_before size_icon").find("div", class_="tax-value")
            para_size = cont_size.get_text(strip=True)
            rawbirdata.at[index, "size"] = para_size

        if soup.find("div", class_="tax-item icons_dictionary_before color_icon") != None:
            cont_color = soup.find("div", class_="tax-item icons_dictionary_before color_icon").find("div", class_="tax-value")
            para_color = cont_color.get_text(strip=True)
            rawbirdata.at[index, "color"] = para_color

        binocs = soup.find_all("div", class_="tax-item icons_dictionary_before binoculars_icon")
        for binoc in binocs:
            if binoc.find("div", class_="tax-title").get_text(strip=True) == "Wing Shape":
                cont_wingshape = binoc.find("div", class_="tax-value")
                para_wingshape = cont_wingshape.get_text(strip=True)
                rawbirdata.at[index, "wing_shape"] = para_wingshape
            else:
                cont_tailshape = binoc.find("div", class_="tax-value")
                para_tailshape = cont_tailshape.get_text(strip=True)
                rawbirdata.at[index, "tail_shape"] = para_tailshape  


        


    

    #DESCRIPTION
    cont_desc = soup.find("div", class_="bird_info_item info_description").find("div", class_="content")
    para_desc = cont_desc.get_text(strip=True)
    rawbirdata.at[index, "description"] = para_desc

    #HABITAT
    cont_habitat = soup.find("div", class_="bird_info_item info_habitat").find("div", class_="content")
    para_habitat = cont_habitat.get_text(strip=True)
    rawbirdata.at[index, "habitat_ext"] = para_habitat

    #EGGS
    cont_eggs = soup.find("div", class_="bird_info_item info_eggs").find("div", class_="content")
    para_eggs = cont_eggs.get_text(strip=True)
    rawbirdata.at[index, "eggs"] = para_eggs

    #FEEDING BEHAVIOR
    cont_feed = soup.find("div", class_="bird_info_item info_feeding").find("div", class_="content")
    para_feed = cont_feed.get_text(strip=True)
    rawbirdata.at[index, "feeding_behavior"] = para_feed

    #YOUNG
    cont_young = soup.find("div", class_="bird_info_item info_young").find("div", class_="content")
    para_young = cont_young.get_text(strip=True)
    rawbirdata.at[index, "young"] = para_young

    #NESTING
    cont_nest = soup.find("div", class_="bird_info_item info_nesting").find("div", class_="content")
    para_nest = cont_nest.get_text(strip=True)
    rawbirdata.at[index, "nesting"] = para_nest

    #DIET
    cont_diet = soup.find("div", class_="bird_info_item info_diet").find("div", class_="content")
    para_diet = cont_diet.get_text(strip=True)
    rawbirdata.at[index, "diet"] = para_diet
rawbirdata.head()
# Out:
# Exception ignored in: <function Service.__del__ at 0x000001F98E6199E0>
# Traceback (most recent call last):
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\common\service.py", line 189, in __del__
#     self.stop()
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\common\service.py", line 146, in stop
#     self.send_remote_shutdown_command()
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\common\service.py", line 126, in send_remote_shutdown_command
#     request.urlopen(f"{self.service_url}/shutdown")
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\urllib\request.py", line 216, in urlopen
#     return opener.open(url, data, timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\urllib\request.py", line 519, in open
#     response = self._open(req, data)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\urllib\request.py", line 536, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\urllib\request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\urllib\request.py", line 1377, in http_open
#     return self.do_open(http.client.HTTPConnection, req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\urllib\request.py", line 1348, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\http\client.py", line 1286, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\http\client.py", line 1332, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\http\client.py", line 1281, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\http\client.py", line 1041, in _send_output
#     self.send(msg)
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\http\client.py", line 979, in send
#     self.connect()
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\http\client.py", line 945, in connect
#     self.sock = self._create_connection(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\socket.py", line 843, in create_connection
#     exceptions.clear()  # raise only the last error
#     ^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 8
#       5 soup = BeautifulSoup(response.content, "html.parser")
#       7 #CALL AUDIOS
# ----> 8 rawbirdata.at[index, 'calls_audio'] = getSounds(bird_url)
#      10 #RANGE IMAGE
#      11 rawbirdata.at[index, 'range_image'] = getRange(bird_url)
#
# Cell In[10], line 25, in getSounds(urly)
#      22 # Parse the HTML using Beautiful Soup
#      23 soup = BeautifulSoup(HTML, 'html.parser')
# ---> 25 soundivs = soup.find('div', id='info_sounds').find('div', class_='bird-songs-calls').find_all('figure', class_='track')
#      27 dicBird = {}
#      29 for soundiv in soundivs:
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
print(rawbirdata["images"].iloc[0])
rawbirdata.head(21)
# Out:
# ['https://media.audubon.org/nas_birdapi_hero/h_a1_3725_3_northern-cardinal_carole_wiley_kk_adult-male-and-adult-female_0.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/a1_4524_2_northern-cardinal_diane_wurzer_kk_adult-male.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/apa_2015_donaldbrown_279112_northern_cardinal_kk_adult-female.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/a1_4883_3_northern-cardinal_anthony_louviere_kk_adult-male.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/northern-cardinal_001_juvenile_summer_maryland_ehpien_flickrcc-by-nc-nd-2.0_molting-juvenile.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/a1_6762_4_northern-cardinal-female_rosemary_gillan_adult-female.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/a1_5424_6_northern-cardinal_jocelyn_anderson_adult-male.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/northern-cardinal_002_juvenile_summer_maryland_ehpien_flickrcc-by-nc-nd-2.0_molting-juvenile.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/apa_2011_19862_156843_kathleenjohnston_northern_cardinal_kk_molting-adult-female.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/a1_6169_1_northern-cardinal_marie_plummer_adult-male.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/northern-cardinal_003_juvenile_summer_maryland_ehpien_flickrcc-by-nc-nd-2.0_juvenile.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/apa_2012_25031_193841_donaldwuori_northern_cardinal_kk_adult-male-and-adult-female.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/a1_6922_1_cardianlis-northern-cardinal_douglas_chewning_adult-male.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/apa_2013_29124_231347_donaldwuori_northern_cardinal_kk_adult-female.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/northern-cardinal_004_juvenile_summer_maryland_ehpien_flickrcc-by-nc-nd-2.0_molting-juvenile.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/apa_2011_19663_156330_sheldongoldstein_northern_cardinal_kk_adult-male.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale', 'https://media.audubon.org/nas_birdapi/apa_2015_darlajoathout_276940_northern_cardinal_kk_adult-female.jpg?width=380&height=255&auto=webp&quality=90&fit=crop&enable=upscale']
#                     name                 sciname               webname  \
# 0      Northern Cardinal   Cardinalis cardinalis     northern-cardinal
# 1             Barred Owl             Strix varia            barred-owl
# 2               Blue Jay     Cyanocitta cristata              blue-jay
# 3        Red-tailed Hawk       Buteo jamaicensis       red-tailed-hawk
# 4       Great Horned Owl        Bubo virginianus      great-horned-owl
# 5            House Finch    Haemorhous mexicanus           house-finch
# 6           Gray Catbird  Dumetella carolinensis          gray-catbird
# 7          Mourning Dove        Zenaida macroura         mourning-dove
# 8          American Crow   Corvus brachyrhynchos         american-crow
# 9         American Robin      Turdus migratorius        american-robin
# 10         Cooper's Hawk      Accipiter cooperii          coopers-hawk
# 11    American Goldfinch          Spinus tristis    american-goldfinch
# 12  Northern Mockingbird       Mimus polyglottos  northern-mockingbird
# 13          Common Raven            Corvus corax          common-raven
# 14        Indigo Bunting        Passerina cyanea        indigo-bunting
# 15      Great Blue Heron          Ardea herodias      great-blue-heron
# 16            House Wren       Troglodytes aedon            house-wren
# 17                   NaN                     NaN   pileated-woodpecker
# 18                   NaN                     NaN      northern-flicker
# 19                   NaN                     NaN       dark-eyed-junco
# 20                   NaN                     NaN   eastern-screech-owl
#
#                                             at_glance  \
# 0   One of our most popular birds, the Cardinal is...
# 1   The rich baritone hooting of the Barred Owl is...
# 2   One of the loudest and most colorful birds of ...
# 3   This is the most widespread and familiar large...
# 4   Found almost throughout North America and much...
# 5   Adaptable, colorful, and cheery-voiced, House ...
# 6   Rather plain but with lots of personality, the...
# 7   The mournful cooing of the Mourning Dove is on...
# 8   Crows are thought to be among our most intelli...
# 9   A very familiar bird over most of North Americ...
# 10  A medium-sized hawk of the woodlands. Feeding ...
# 11  A typical summer sight is a male American Gold...
# 12  This bird's famous song, with its varied repet...
# 13  Of the birds classified as perching birds or '...
# 14  In parts of the East, Indigo Bunting may be th...
# 15  Widespread and familiar (though often called '...
# 16  A familiar backyard bird, the House Wren was n...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
#
#                                         category conservation  \
# 0                      Cardinals, Perching Birds  Low Concern
# 1                                           Owls  Low Concern
# 2           Crows, Magpies, Jays, Perching Birds  Low Concern
# 3              Hawk-like Birds, Hawks and Eagles  Low Concern
# 4                                           Owls  Low Concern
# 5                        Finches, Perching Birds  Low Concern
# 6     Mockingbirds and Thrashers, Perching Birds  Low Concern
# 7           Pigeon-like Birds, Pigeons and Doves  Low Concern
# 8                                            NaN  Low Concern
# 9                       Perching Birds, Thrushes  Low Concern
# 10             Hawk-like Birds, Hawks and Eagles  Low Concern
# 11                       Finches, Perching Birds  Low Concern
# 12    Mockingbirds and Thrashers, Perching Birds  Low Concern
# 13          Crows, Magpies, Jays, Perching Birds  Low Concern
# 14                     Cardinals, Perching Birds  Low Concern
# 15  Herons, Egrets, Bitterns, Long-legged Waders  Low Concern
# 16                         Perching Birds, Wrens  Low Concern
# 17                                           NaN          NaN
# 18                                           NaN          NaN
# 19                                           NaN          NaN
# 20                                           NaN          NaN
#
#                                               habitat  \
# 0   Arroyos and Canyons, Desert and Arid Habitats,...
# 1   Forests and Woodlands, Freshwater Wetlands, La...
# 2   Coasts and Shorelines, Fields, Meadows, and Gr...
# 3   Coasts and Shorelines, Desert and Arid Habitat...
# 4   Coasts and Shorelines, Desert and Arid Habitat...
# 5   Arroyos and Canyons, Desert and Arid Habitats,...
# 6   Fields, Meadows, and Grasslands, Forests and W...
# 7   Coasts and Shorelines, Desert and Arid Habitat...
# 8                                                 NaN
# 9   Arroyos and Canyons, Coasts and Shorelines, De...
# 10  Arroyos and Canyons, Coasts and Shorelines, Fi...
# 11  Arroyos and Canyons, Fields, Meadows, and Gras...
# 12  Arroyos and Canyons, Desert and Arid Habitats,...
# 13  Arroyos and Canyons, Coasts and Shorelines, De...
# 14  Arroyos and Canyons, Fields, Meadows, and Gras...
# 15  Coasts and Shorelines, Forests and Woodlands, ...
# 16  Arroyos and Canyons, Desert and Arid Habitats,...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
#
#                                                region  \
# 0   Eastern Canada, Florida, Great Lakes, Mid Atla...
# 1   California, Eastern Canada, Florida, Great Lak...
# 2   California, Eastern Canada, Florida, Great Lak...
# 3   Alaska and The North, California, Eastern Cana...
# 4   Alaska and The North, California, Eastern Cana...
# 5   California, Eastern Canada, Florida, Great Lak...
# 6   California, Eastern Canada, Florida, Great Lak...
# 7   Alaska and The North, California, Eastern Cana...
# 8   Alaska and The North, California, Eastern Cana...
# 9   Alaska and The North, California, Eastern Cana...
# 10  California, Eastern Canada, Florida, Great Lak...
# 11  California, Eastern Canada, Florida, Great Lak...
# 12  California, Eastern Canada, Florida, Great Lak...
# 13  Alaska and The North, California, Eastern Cana...
# 14  California, Eastern Canada, Florida, Great Lak...
# 15  Alaska and The North, California, Eastern Cana...
# 16  California, Eastern Canada, Florida, Great Lak...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
#
#                                            behavior   population  ...  \
# 0                    Flitter, Formation, Undulating  130.000.000  ...
# 1                              Flap/Glide, Hovering    3.500.000  ...
# 2   Direct Flight, Flap/Glide, Hovering, Undulating   17.000.000  ...
# 3                            Direct Flight, Soaring    3.100.000  ...
# 4                                               NaN    5.700.000  ...
# 5              Flitter, Rapid Wingbeats, Undulating   40.000.000  ...
# 6                            Direct Flight, Flitter   29.000.000  ...
# 7                                     Direct Flight  150.000.000  ...
# 8                                     Direct Flight   28.000.000  ...
# 9                            Direct Flight, Running  370.000.000  ...
# 10                              Flap/Glide, Soaring    1.000.000  ...
# 11             Flitter, Rapid Wingbeats, Undulating   44.000.000  ...
# 12                   Direct Flight, Rapid Wingbeats   43.000.000  ...
# 13                           Direct Flight, Soaring   29.000.000  ...
# 14                                    Direct Flight   77.000.000  ...
# 15                           Direct Flight, Soaring      700.000  ...
# 16                           Direct Flight, Flitter  190.000.000  ...
# 17                                              NaN          NaN  ...
# 18                                              NaN          NaN  ...
# 19                                              NaN          NaN  ...
# 20                                              NaN          NaN  ...
#
#                                   call_pattern  \
# 0                                      Falling
# 1                 Complex, Falling, Undulating
# 2                                Falling, Flat
# 3                              Falling, Simple
# 4                                          NaN
# 5         Complex, Falling, Rising, Undulating
# 6                    Falling, Flat, Undulating
# 7                    Falling, Flat, Undulating
# 8                        Falling, Flat, Simple
# 9                             Flat, Undulating
# 10                                Flat, Simple
# 11                Complex, Falling, Undulating
# 12  Complex, Falling, Flat, Rising, Undulating
# 13                                Flat, Simple
# 14                Complex, Falling, Undulating
# 15                                Flat, Simple
# 16                         Falling, Undulating
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
#
#                                        call_type  \
# 0                            Chirp/Chip, Whistle
# 1                                           Hoot
# 2   Chirp/Chip, Rattle, Raucous, Scream, Whistle
# 3                                         Scream
# 4                                            NaN
# 5                 Chirp/Chip, Hi, Trill, Whistle
# 6       Chatter, Chirp/Chip, Hi, Scream, Whistle
# 7                                           Hoot
# 8                                Rattle, Raucous
# 9                     Chirp/Chip, Flute, Whistle
# 10                               Chatter, Scream
# 11              Chatter, Chirp/Chip, Hi, Whistle
# 12     Chatter, Chirp/Chip, Odd, Scream, Whistle
# 13                     Croak/Quack, Odd, Raucous
# 14                     Buzz, Chirp/Chip, Whistle
# 15                           Croak/Quack, Scream
# 16                    Chirp/Chip, Trill, Whistle
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
# 20                                           NaN
#
#                                           calls_audio  \
# 0   {'Songs #1': 'https://media.audubon.org/nas_bi...
# 1   {'Classic hoots #1': 'https://media.audubon.or...
# 2   {'Jay calls & clicks': 'https://media.audubon....
# 3   {'Typical calls #1': 'https://media.audubon.or...
# 4   {'Hoots of pair': 'https://media.audubon.org/n...
# 5   {'Song #1': 'https://media.audubon.org/nas_bir...
# 6   {'Song #1': 'https://media.audubon.org/nas_bir...
# 7   {'Coo & partial coo': 'https://media.audubon.o...
# 8   {'Caws #1': 'https://media.audubon.org/nas_bir...
# 9   {'Song #1': 'https://media.audubon.org/nas_bir...
# 10  {'Cak-series': 'https://media.audubon.org/nas_...
# 11  {'Song #1': 'https://media.audubon.org/nas_bir...
# 12  {'Song #1': 'https://media.audubon.org/nas_bir...
# 13  {'Various calls': 'https://media.audubon.org/n...
# 14  {'Song #1': 'https://media.audubon.org/nas_bir...
# 15  {'Croaks given upon landing': 'https://media.a...
# 16  {'Song #1': 'https://media.audubon.org/nas_bir...
# 17                                                 {}
# 18                                                 {}
# 19                                                 {}
# 20                                                 {}
#
#                                           habitat_ext  \
# 0   Woodland edges, thickets, suburban gardens, to...
# 1   Woodlands, wooded river bottoms, wooded swamps...
# 2   Oak and pine woods, suburban gardens, groves, ...
# 3   Open country, woodlands, prairie groves, mount...
# 4   Forests, woodlots, streamsides, open country. ...
# 5   Cities, suburbs, farms, canyons. Original habi...
# 6   Undergrowth, brush, thorn scrub, suburban gard...
# 7   Farms, towns, open woods, roadsides, grassland...
# 8   Woodlands, farms, fields, river groves, shores...
# 9   Cities, towns, lawns, farmland, forests; in wi...
# 10  Mature forest, open woodlands, wood edges, riv...
# 11  Patches of thistles and weeds, roadsides, open...
# 12  Towns, farms, roadsides, thickets, brushy area...
# 13  Boreal and mountain forests, coastal cliffs, t...
# 14  Brushy pastures, bushy wood edges. For nesting...
# 15  Marshes, swamps, shores, tideflats. Very adapt...
# 16  Open woods, thickets, towns, gardens. Breeds i...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
#
#                                                  eggs  \
# 0   3-4, sometimes 2-5. Whitish to pale bluish or ...
# 1   2-3, rarely 4. White. Incubation is mostly or ...
# 2   4-5, sometimes 3-7. Greenish or buff, sometime...
# 3   2-3, sometimes 4, rarely 1-5. Whitish, blotche...
# 4   2-3, sometimes 1-5, rarely 6. Dull whitish. In...
# 5   4-5, sometimes 2-6. Pale blue, with black and ...
# 6   4, sometimes 3-5, rarely 2-6. Greenish blue, r...
# 7   2. White. Incubation is by both parents, about...
# 8   4-6, sometimes 3-9. Dull blue-green to gray-gr...
# 9   Usually 4, sometimes 3-7. Pale blue or "robin'...
# 10  3-5, sometimes 1-7. Pale bluish-white. Incubat...
# 11  4-6, sometimes 2-7. Pale bluish white, occasio...
# 12  3-4, sometimes 2-6. Variably greenish to bluis...
# 13  4-6, sometimes 3-7. Greenish, blotched with ol...
# 14  3-4, rarely 1-2. White to bluish-white, rarely...
# 15  3-5, sometimes 2-7. Pale blue. Incubation is b...
# 16  6-7, sometimes 5-8, occasionally more. White, ...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
#
#                                                 young  \
# 0   Both parents feed nestlings. Young leave nest ...
# 1   Female may remain with young much of time at f...
# 2   Both parents bring food for nestlings. Young l...
# 3   Female remains with young most of the time dur...
# 4   Both parents take part in providing food for y...
# 5   Both parents feed nestlings. Young leave the n...
# 6   Both parents feed the nestlings. Young leave t...
# 7   Both parents feed young "pigeon milk." Young l...
# 8   Fed by both parents and sometimes by "helpers....
# 9   Both parents feed young, though female does mo...
# 10  Female broods young during first 2 weeks after...
# 11  Both parents feed nestlings. At first male bri...
# 12  Both parents feed the nestlings. Young leave t...
# 13  Both parents bring food for nestlings, and fem...
# 14  Fed only by female in most cases. At some nest...
# 15  Both parents feed young, by regurgitation. You...
# 16  Probably both parents feed nestlings. Young le...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
#
#                                      feeding_behavior  \
# 0   Forages mostly while hopping on ground or in l...
# 1   Hunts by night or day, perhaps most at dawn an...
# 2   Forages in trees and shrubs and on ground. Com...
# 3   Does most hunting by watching from a high perc...
# 4   Hunts mostly at night, sometimes at dusk. Watc...
# 5   Forages on ground, while perching in weeds, or...
# 6   Does much foraging on ground, flipping leaves ...
# 7   Forages mostly on ground; sometimes will perch...
# 8   Opportunistic, quickly taking advantage of new...
# 9   Does much foraging on the ground, running and ...
# 10  Usually hunts by stealth, moving from perch to...
# 11  Forages actively in weeds, shrubs, and trees, ...
# 12  Captures insects mostly while walking and runn...
# 13  Typically forages in pairs, the two birds some...
# 14  Forages at all levels from ground up into shru...
# 15  Forages mostly by standing still or walking ve...
# 16  Forages very actively in dense vegetation. For...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
#
#                                                  diet  \
# 0   Mostly seeds, insects, berries. Diet is quite ...
# 1   Mostly small mammals. Eats many mice and other...
# 2   Omnivorous. Most of diet is vegetable matter (...
# 3   Varied, includes small mammals, birds, reptile...
# 4   Varied, mostly mammals and birds. Mammals make...
# 5   Mostly seeds, buds, berries. Almost all of die...
# 6   Mostly insects and berries. Especially in earl...
# 7   Seeds. Feeds almost entirely on seeds (99% of ...
# 8   Omnivorous. Seems to feed on practically anyth...
# 9   Mostly insects, berries, earthworms. In early ...
# 10  Mostly birds and small mammals. Feeds mainly o...
# 11  Mostly seeds, some insects. Diet is primarily ...
# 12  Mostly insects and berries. Annual diet is abo...
# 13  Omnivorous. May feed on practically anything, ...
# 14  Mostly seeds and insects. In breeding season f...
# 15  Highly variable and adaptable. Eats mostly fis...
# 16  Mostly insects. Feeds on a wide variety of ins...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
#
#                                               nesting  \
# 0   Male sings to defend nesting territory, active...
# 1   Courtship involves both male and female bobbin...
# 2   Courtship may involve aerial chases; male may ...
# 3   In courtship, male and female soar in high cir...
# 4   May begin nesting very early in north (late wi...
# 5   Pairs may begin to form within flocks in winte...
# 6   Early in breeding season, male sings constantl...
# 7   In courtship, male flies up with noisy wingbea...
# 8   In courtship on ground or in tree, male faces ...
# 9   Males arrive before females on nesting grounds...
# 10  In courtship (and occasionally at other times)...
# 11  Nesting begins late in season in many areas, w...
# 12  Nesting begins early, by late winter in southe...
# 13  In courtship display, male soars, swoops, and ...
# 14  Male establishes territory in spring, defends ...
# 15  Breeds in colonies, often of this species alon...
# 16  Male defends territory by singing. Courtship i...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
#
#                                                images
# 0   [https://media.audubon.org/nas_birdapi_hero/h_...
# 1   [https://media.audubon.org/nas_birdapi_hero/we...
# 2   [https://media.audubon.org/nas_birdapi_hero/sf...
# 3   [https://media.audubon.org/nas_birdapi_hero/h_...
# 4   [https://media.audubon.org/nas_birdapi_hero/we...
# 5   [https://media.audubon.org/nas_birdapi_hero/h_...
# 6   [https://media.audubon.org/nas_birdapi_hero/we...
# 7   [https://media.audubon.org/nas_birdapi_hero/h_...
# 8   [https://media.audubon.org/nas_birdapi_hero/we...
# 9   [https://media.audubon.org/nas_birdapi_hero/we...
# 10  [https://media.audubon.org/nas_birdapi_hero/a1...
# 11  [https://media.audubon.org/nas_birdapi_hero/h_...
# 12  [https://media.audubon.org/nas_birdapi_hero/a1...
# 13  [https://media.audubon.org/nas_birdapi_hero/h_...
# 14  [https://media.audubon.org/nas_birdapi_hero/h_...
# 15  [https://media.audubon.org/nas_birdapi_hero/h_...
# 16  [https://media.audubon.org/nas_birdapi_hero/ho...
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20                                                 []
#
# [21 rows x 26 columns]

# %%
dummyRows = pd.read_csv("test4birds - test4birds.csv (1).csv")
main_folder = 'bird_images'
if not os.path.exists(main_folder):
    os.makedirs(main_folder)

# Iterate over each row in the DataFrame
for index, row in dummyRows.iterrows():
    # Extract the bird name and the list of image URLs
    bird_name = row['name']
    image_urls = row['images']
    if image_urls != None:
    
        # Create a folder for the current bird within the main folder
        bird_folder = os.path.join(main_folder, bird_name)
        if not os.path.exists(bird_folder):
            os.makedirs(bird_folder)
        
        # Download images for the current bird
        for i, url in enumerate(image_urls):
            try:
                response = requests.get(url)
                if response.status_code == 200:
                    # Save the image with a unique name within the bird's folder
                    with open(os.path.join(bird_folder, f'{bird_name}_{i}.jpg'), 'wb') as f:
                        f.write(response.content)
            except Exception as e:
                print(f"Error downloading image {i+1} for {bird_name}: {e}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 10
#       7 for index, row in dummyRows.iterrows():
#       8     # Extract the bird name and the list of image URLs
#       9     bird_name = row['name']
# ---> 10     print(type(image_urls = row['images']))
#      11     if image_urls != None:
#      12
#      13         # Create a folder for the current bird within the main folder
#      14         bird_folder = os.path.join(main_folder, bird_name)
#
# TypeError: type() takes 1 or 3 arguments

# %%
dummyRows.head()
# Out:
#    Unnamed: 0               name                sciname            webname  \
# 0           0  Northern Cardinal  Cardinalis cardinalis  northern-cardinal
# 1           1         Barred Owl            Strix varia         barred-owl
# 2           2           Blue Jay    Cyanocitta cristata           blue-jay
# 3           3    Red-tailed Hawk      Buteo jamaicensis    red-tailed-hawk
# 4           4   Great Horned Owl       Bubo virginianus   great-horned-owl
#
#                                            at_glance  \
# 0  One of our most popular birds, the Cardinal is...
# 1  The rich baritone hooting of the Barred Owl is...
# 2  One of the loudest and most colorful birds of ...
# 3  This is the most widespread and familiar large...
# 4  Found almost throughout North America and much...
#
#                                category conservation  \
# 0             Cardinals, Perching Birds  Low Concern
# 1                                  Owls  Low Concern
# 2  Crows, Magpies, Jays, Perching Birds  Low Concern
# 3     Hawk-like Birds, Hawks and Eagles  Low Concern
# 4                                  Owls  Low Concern
#
#                                              habitat  \
# 0  Arroyos and Canyons, Desert and Arid Habitats,...
# 1  Forests and Woodlands, Freshwater Wetlands, La...
# 2  Coasts and Shorelines, Fields, Meadows, and Gr...
# 3  Coasts and Shorelines, Desert and Arid Habitat...
# 4  Coasts and Shorelines, Desert and Arid Habitat...
#
#                                               region  \
# 0  Eastern Canada, Florida, Great Lakes, Mid Atla...
# 1  California, Eastern Canada, Florida, Great Lak...
# 2  California, Eastern Canada, Florida, Great Lak...
# 3  Alaska and The North, California, Eastern Cana...
# 4  Alaska and The North, California, Eastern Cana...
#
#                                           behavior  ...  \
# 0                   Flitter, Formation, Undulating  ...
# 1                             Flap/Glide, Hovering  ...
# 2  Direct Flight, Flap/Glide, Hovering, Undulating  ...
# 3                           Direct Flight, Soaring  ...
# 4                                              NaN  ...
#
#                    call_pattern                                     call_type  \
# 0                       Falling                           Chirp/Chip, Whistle
# 1  Complex, Falling, Undulating                                          Hoot
# 2                 Falling, Flat  Chirp/Chip, Rattle, Raucous, Scream, Whistle
# 3               Falling, Simple                                        Scream
# 4                           NaN                                           NaN
#
#                                          calls_audio  \
# 0  {'Songs #1': 'https://media.audubon.org/nas_bi...
# 1  {'Classic hoots #1': 'https://media.audubon.or...
# 2  {'Jay calls & clicks': 'https://media.audubon....
# 3  {'Typical calls #1': 'https://media.audubon.or...
# 4  {'Hoots of pair': 'https://media.audubon.org/n...
#
#                                          habitat_ext  \
# 0  Woodland edges, thickets, suburban gardens, to...
# 1  Woodlands, wooded river bottoms, wooded swamps...
# 2  Oak and pine woods, suburban gardens, groves, ...
# 3  Open country, woodlands, prairie groves, mount...
# 4  Forests, woodlots, streamsides, open country. ...
#
#                                                 eggs  \
# 0  3-4, sometimes 2-5. Whitish to pale bluish or ...
# 1  2-3, rarely 4. White. Incubation is mostly or ...
# 2  4-5, sometimes 3-7. Greenish or buff, sometime...
# 3  2-3, sometimes 4, rarely 1-5. Whitish, blotche...
# 4  2-3, sometimes 1-5, rarely 6. Dull whitish. In...
#
#                                                young  \
# 0  Both parents feed nestlings. Young leave nest ...
# 1  Female may remain with young much of time at f...
# 2  Both parents bring food for nestlings. Young l...
# 3  Female remains with young most of the time dur...
# 4  Both parents take part in providing food for y...
#
#                                     feeding_behavior  \
# 0  Forages mostly while hopping on ground or in l...
# 1  Hunts by night or day, perhaps most at dawn an...
# 2  Forages in trees and shrubs and on ground. Com...
# 3  Does most hunting by watching from a high perc...
# 4  Hunts mostly at night, sometimes at dusk. Watc...
#
#                                                 diet  \
# 0  Mostly seeds, insects, berries. Diet is quite ...
# 1  Mostly small mammals. Eats many mice and other...
# 2  Omnivorous. Most of diet is vegetable matter (...
# 3  Varied, includes small mammals, birds, reptile...
# 4  Varied, mostly mammals and birds. Mammals make...
#
#                                              nesting  \
# 0  Male sings to defend nesting territory, active...
# 1  Courtship involves both male and female bobbin...
# 2  Courtship may involve aerial chases; male may ...
# 3  In courtship, male and female soar in high cir...
# 4  May begin nesting very early in north (late wi...
#
#                                               images
# 0  ['https://media.audubon.org/nas_birdapi_hero/h...
# 1  ['https://media.audubon.org/nas_birdapi_hero/w...
# 2  ['https://media.audubon.org/nas_birdapi_hero/s...
# 3  ['https://media.audubon.org/nas_birdapi_hero/h...
# 4  ['https://media.audubon.org/nas_birdapi_hero/w...
#
# [5 rows x 27 columns]

# %%
main_audio_folder = 'bird_audios'
if not os.path.exists(main_audio_folder):
    os.makedirs(main_audio_folder)

# Iterate over each row in the DataFrame
for index, row in rawbirdata.iterrows():
    # Extract the bird name and the list of image URLs
    bird_audio_name = row['name']
    audio_urls = row['calls_audio']
    print(audio_urls)
    if audio_urls != None:
    
        # Create a folder for the current bird within the main folder
        bird_audio_folder = os.path.join(main_audio_folder, bird_audio_name)
        if not os.path.exists(bird_audio_folder):
            os.makedirs(bird_audio_folder)
        
        # Download images for the current bird
        for name, url in audio_urls.items():
            print(url)
            try:
                response = requests.get(url)
                if response.status_code == 200:
                    # Save the image with a unique name within the bird's folder
                    with open(os.path.join(bird_audio_folder, f'{bird_audio_name}_{name}.mp3'), 'wb') as f:
                        f.write(response.content)
            except Exception as e:
                print(f"Error downloading audio {name} for {bird_audio_name}: {e}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       3     os.makedirs(main_audio_folder)
#       5 # Iterate over each row in the DataFrame
# ----> 6 for index, row in rawbirdata.iterrows():
#       7     # Extract the bird name and the list of image URLs
#       8     bird_audio_name = row['name']
#       9     audio_urls = row['calls_audio']
#
# NameError: name 'rawbirdata' is not defined

# %%
if not os.path.exists('bird_ranges'):
    os.makedirs('bird_ranges')

# Sample DataFrame
# Assuming df is your DataFrame with 'name' and 'link_source' columns
# df = pd.read_csv('your_dataframe.csv')  # Load your DataFrame from a CSV file if needed

# Iterate over each row of the DataFrame
for index, row in rawbirdata.iterrows():
    bird_name = row['name']
    image_url = row['range_image']
    
    # Download the image
    response = requests.get(image_url)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Save the image to the 'bird_ranges' folder
        with open(f'bird_ranges/{bird_name}.jpg', 'wb') as f:
            f.write(response.content)
        print(f"Image downloaded for {bird_name}")
    else:
        print(f"Failed to download image for {bird_name}")
# Out:
# Image downloaded for Northern Cardinal
# Image downloaded for Barred Owl
# Image downloaded for Blue Jay
# Image downloaded for Red-tailed Hawk
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[76], line 14
#      11 image_url = row['range_image']
#      13 # Download the image
# ---> 14 response = requests.get(image_url)
#      16 # Check if the request was successful
#      17 if response.status_code == 200:
#      18     # Save the image to the 'bird_ranges' folder
#
# File c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\site-packages\requests\sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\site-packages\requests\sessions.py:486, in Session.prepare_request(self, request)
#     483     auth = get_netrc_auth(request.url)
#     485 p = PreparedRequest()
# --> 486 p.prepare(
#     487     method=request.method.upper(),
#     488     url=request.url,
#     489     files=request.files,
#     490     data=request.data,
#     491     json=request.json,
#     492     headers=merge_setting(
#     493         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     494     ),
#     495     params=merge_setting(request.params, self.params),
#     496     auth=merge_setting(auth, self.auth),
#     497     cookies=merged_cookies,
#     498     hooks=merge_hooks(request.hooks, self.hooks),
#     499 )
#     500 return p
#
# File c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\site-packages\requests\models.py:368, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     365 """Prepares the entire request with the given parameters."""
#     367 self.prepare_method(method)
# --> 368 self.prepare_url(url, params)
#     369 self.prepare_headers(headers)
#     370 self.prepare_cookies(cookies)
#
# File c:\Users\evandenkooy\AppData\Local\anaconda3\Lib\site-packages\requests\models.py:439, in PreparedRequest.prepare_url(self, url, params)
#     436     raise InvalidURL(*e.args)
#     438 if not scheme:
# --> 439     raise MissingSchema(
#     440         f"Invalid URL {url!r}: No scheme supplied. "
#     441         f"Perhaps you meant https://{url}?"
#     442     )
#     444 if not host:
#     445     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
#
# MissingSchema: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?

# %%
subset_toHeron = rawbirdata.head(16)
subset_toHeron.head(20)
# Out:
#                     name                 sciname               webname  \
# 0      Northern Cardinal   Cardinalis cardinalis     northern-cardinal
# 1             Barred Owl             Strix varia            barred-owl
# 2               Blue Jay     Cyanocitta cristata              blue-jay
# 3        Red-tailed Hawk       Buteo jamaicensis       red-tailed-hawk
# 4       Great Horned Owl        Bubo virginianus      great-horned-owl
# 5            House Finch    Haemorhous mexicanus           house-finch
# 6           Gray Catbird  Dumetella carolinensis          gray-catbird
# 7          Mourning Dove        Zenaida macroura         mourning-dove
# 8          American Crow   Corvus brachyrhynchos         american-crow
# 9         American Robin      Turdus migratorius        american-robin
# 10         Cooper's Hawk      Accipiter cooperii          coopers-hawk
# 11    American Goldfinch          Spinus tristis    american-goldfinch
# 12  Northern Mockingbird       Mimus polyglottos  northern-mockingbird
# 13          Common Raven            Corvus corax          common-raven
# 14        Indigo Bunting        Passerina cyanea        indigo-bunting
# 15      Great Blue Heron          Ardea herodias      great-blue-heron
#
#                                             at_glance  \
# 0   One of our most popular birds, the Cardinal is...
# 1   The rich baritone hooting of the Barred Owl is...
# 2   One of the loudest and most colorful birds of ...
# 3   This is the most widespread and familiar large...
# 4   Found almost throughout North America and much...
# 5   Adaptable, colorful, and cheery-voiced, House ...
# 6   Rather plain but with lots of personality, the...
# 7   The mournful cooing of the Mourning Dove is on...
# 8   Crows are thought to be among our most intelli...
# 9   A very familiar bird over most of North Americ...
# 10  A medium-sized hawk of the woodlands. Feeding ...
# 11  A typical summer sight is a male American Gold...
# 12  This bird's famous song, with its varied repet...
# 13  Of the birds classified as perching birds or '...
# 14  In parts of the East, Indigo Bunting may be th...
# 15  Widespread and familiar (though often called '...
#
#                                         category conservation  \
# 0                      Cardinals, Perching Birds  Low Concern
# 1                                           Owls  Low Concern
# 2           Crows, Magpies, Jays, Perching Birds  Low Concern
# 3              Hawk-like Birds, Hawks and Eagles  Low Concern
# 4                                           Owls  Low Concern
# 5                        Finches, Perching Birds  Low Concern
# 6     Mockingbirds and Thrashers, Perching Birds  Low Concern
# 7           Pigeon-like Birds, Pigeons and Doves  Low Concern
# 8                                            NaN  Low Concern
# 9                       Perching Birds, Thrushes  Low Concern
# 10             Hawk-like Birds, Hawks and Eagles  Low Concern
# 11                       Finches, Perching Birds  Low Concern
# 12    Mockingbirds and Thrashers, Perching Birds  Low Concern
# 13          Crows, Magpies, Jays, Perching Birds  Low Concern
# 14                     Cardinals, Perching Birds  Low Concern
# 15  Herons, Egrets, Bitterns, Long-legged Waders  Low Concern
#
#                                               habitat  \
# 0   Arroyos and Canyons, Desert and Arid Habitats,...
# 1   Forests and Woodlands, Freshwater Wetlands, La...
# 2   Coasts and Shorelines, Fields, Meadows, and Gr...
# 3   Coasts and Shorelines, Desert and Arid Habitat...
# 4   Coasts and Shorelines, Desert and Arid Habitat...
# 5   Arroyos and Canyons, Desert and Arid Habitats,...
# 6   Fields, Meadows, and Grasslands, Forests and W...
# 7   Coasts and Shorelines, Desert and Arid Habitat...
# 8                                                 NaN
# 9   Arroyos and Canyons, Coasts and Shorelines, De...
# 10  Arroyos and Canyons, Coasts and Shorelines, Fi...
# 11  Arroyos and Canyons, Fields, Meadows, and Gras...
# 12  Arroyos and Canyons, Desert and Arid Habitats,...
# 13  Arroyos and Canyons, Coasts and Shorelines, De...
# 14  Arroyos and Canyons, Fields, Meadows, and Gras...
# 15  Coasts and Shorelines, Forests and Woodlands, ...
#
#                                                region  \
# 0   Eastern Canada, Florida, Great Lakes, Mid Atla...
# 1   California, Eastern Canada, Florida, Great Lak...
# 2   California, Eastern Canada, Florida, Great Lak...
# 3   Alaska and The North, California, Eastern Cana...
# 4   Alaska and The North, California, Eastern Cana...
# 5   California, Eastern Canada, Florida, Great Lak...
# 6   California, Eastern Canada, Florida, Great Lak...
# 7   Alaska and The North, California, Eastern Cana...
# 8   Alaska and The North, California, Eastern Cana...
# 9   Alaska and The North, California, Eastern Cana...
# 10  California, Eastern Canada, Florida, Great Lak...
# 11  California, Eastern Canada, Florida, Great Lak...
# 12  California, Eastern Canada, Florida, Great Lak...
# 13  Alaska and The North, California, Eastern Cana...
# 14  California, Eastern Canada, Florida, Great Lak...
# 15  Alaska and The North, California, Eastern Cana...
#
#                                            behavior   population  ...  \
# 0                    Flitter, Formation, Undulating  130.000.000  ...
# 1                              Flap/Glide, Hovering    3.500.000  ...
# 2   Direct Flight, Flap/Glide, Hovering, Undulating   17.000.000  ...
# 3                            Direct Flight, Soaring    3.100.000  ...
# 4                                               NaN    5.700.000  ...
# 5              Flitter, Rapid Wingbeats, Undulating   40.000.000  ...
# 6                            Direct Flight, Flitter   29.000.000  ...
# 7                                     Direct Flight  150.000.000  ...
# 8                                     Direct Flight   28.000.000  ...
# 9                            Direct Flight, Running  370.000.000  ...
# 10                              Flap/Glide, Soaring    1.000.000  ...
# 11             Flitter, Rapid Wingbeats, Undulating   44.000.000  ...
# 12                   Direct Flight, Rapid Wingbeats   43.000.000  ...
# 13                           Direct Flight, Soaring   29.000.000  ...
# 14                                    Direct Flight   77.000.000  ...
# 15                           Direct Flight, Soaring      700.000  ...
#
#                                   call_pattern  \
# 0                                      Falling
# 1                 Complex, Falling, Undulating
# 2                                Falling, Flat
# 3                              Falling, Simple
# 4                                          NaN
# 5         Complex, Falling, Rising, Undulating
# 6                    Falling, Flat, Undulating
# 7                    Falling, Flat, Undulating
# 8                        Falling, Flat, Simple
# 9                             Flat, Undulating
# 10                                Flat, Simple
# 11                Complex, Falling, Undulating
# 12  Complex, Falling, Flat, Rising, Undulating
# 13                                Flat, Simple
# 14                Complex, Falling, Undulating
# 15                                Flat, Simple
#
#                                        call_type  \
# 0                            Chirp/Chip, Whistle
# 1                                           Hoot
# 2   Chirp/Chip, Rattle, Raucous, Scream, Whistle
# 3                                         Scream
# 4                                            NaN
# 5                 Chirp/Chip, Hi, Trill, Whistle
# 6       Chatter, Chirp/Chip, Hi, Scream, Whistle
# 7                                           Hoot
# 8                                Rattle, Raucous
# 9                     Chirp/Chip, Flute, Whistle
# 10                               Chatter, Scream
# 11              Chatter, Chirp/Chip, Hi, Whistle
# 12     Chatter, Chirp/Chip, Odd, Scream, Whistle
# 13                     Croak/Quack, Odd, Raucous
# 14                     Buzz, Chirp/Chip, Whistle
# 15                           Croak/Quack, Scream
#
#                                           calls_audio  \
# 0   {'Songs #1': 'https://media.audubon.org/nas_bi...
# 1   {'Classic hoots #1': 'https://media.audubon.or...
# 2   {'Jay calls & clicks': 'https://media.audubon....
# 3   {'Typical calls #1': 'https://media.audubon.or...
# 4   {'Hoots of pair': 'https://media.audubon.org/n...
# 5   {'Song #1': 'https://media.audubon.org/nas_bir...
# 6   {'Song #1': 'https://media.audubon.org/nas_bir...
# 7   {'Coo & partial coo': 'https://media.audubon.o...
# 8   {'Caws #1': 'https://media.audubon.org/nas_bir...
# 9   {'Song #1': 'https://media.audubon.org/nas_bir...
# 10  {'Cak-series': 'https://media.audubon.org/nas_...
# 11  {'Song #1': 'https://media.audubon.org/nas_bir...
# 12  {'Song #1': 'https://media.audubon.org/nas_bir...
# 13  {'Various calls': 'https://media.audubon.org/n...
# 14  {'Song #1': 'https://media.audubon.org/nas_bir...
# 15  {'Croaks given upon landing': 'https://media.a...
#
#                                           habitat_ext  \
# 0   Woodland edges, thickets, suburban gardens, to...
# 1   Woodlands, wooded river bottoms, wooded swamps...
# 2   Oak and pine woods, suburban gardens, groves, ...
# 3   Open country, woodlands, prairie groves, mount...
# 4   Forests, woodlots, streamsides, open country. ...
# 5   Cities, suburbs, farms, canyons. Original habi...
# 6   Undergrowth, brush, thorn scrub, suburban gard...
# 7   Farms, towns, open woods, roadsides, grassland...
# 8   Woodlands, farms, fields, river groves, shores...
# 9   Cities, towns, lawns, farmland, forests; in wi...
# 10  Mature forest, open woodlands, wood edges, riv...
# 11  Patches of thistles and weeds, roadsides, open...
# 12  Towns, farms, roadsides, thickets, brushy area...
# 13  Boreal and mountain forests, coastal cliffs, t...
# 14  Brushy pastures, bushy wood edges. For nesting...
# 15  Marshes, swamps, shores, tideflats. Very adapt...
#
#                                                  eggs  \
# 0   3-4, sometimes 2-5. Whitish to pale bluish or ...
# 1   2-3, rarely 4. White. Incubation is mostly or ...
# 2   4-5, sometimes 3-7. Greenish or buff, sometime...
# 3   2-3, sometimes 4, rarely 1-5. Whitish, blotche...
# 4   2-3, sometimes 1-5, rarely 6. Dull whitish. In...
# 5   4-5, sometimes 2-6. Pale blue, with black and ...
# 6   4, sometimes 3-5, rarely 2-6. Greenish blue, r...
# 7   2. White. Incubation is by both parents, about...
# 8   4-6, sometimes 3-9. Dull blue-green to gray-gr...
# 9   Usually 4, sometimes 3-7. Pale blue or "robin'...
# 10  3-5, sometimes 1-7. Pale bluish-white. Incubat...
# 11  4-6, sometimes 2-7. Pale bluish white, occasio...
# 12  3-4, sometimes 2-6. Variably greenish to bluis...
# 13  4-6, sometimes 3-7. Greenish, blotched with ol...
# 14  3-4, rarely 1-2. White to bluish-white, rarely...
# 15  3-5, sometimes 2-7. Pale blue. Incubation is b...
#
#                                                 young  \
# 0   Both parents feed nestlings. Young leave nest ...
# 1   Female may remain with young much of time at f...
# 2   Both parents bring food for nestlings. Young l...
# 3   Female remains with young most of the time dur...
# 4   Both parents take part in providing food for y...
# 5   Both parents feed nestlings. Young leave the n...
# 6   Both parents feed the nestlings. Young leave t...
# 7   Both parents feed young "pigeon milk." Young l...
# 8   Fed by both parents and sometimes by "helpers....
# 9   Both parents feed young, though female does mo...
# 10  Female broods young during first 2 weeks after...
# 11  Both parents feed nestlings. At first male bri...
# 12  Both parents feed the nestlings. Young leave t...
# 13  Both parents bring food for nestlings, and fem...
# 14  Fed only by female in most cases. At some nest...
# 15  Both parents feed young, by regurgitation. You...
#
#                                      feeding_behavior  \
# 0   Forages mostly while hopping on ground or in l...
# 1   Hunts by night or day, perhaps most at dawn an...
# 2   Forages in trees and shrubs and on ground. Com...
# 3   Does most hunting by watching from a high perc...
# 4   Hunts mostly at night, sometimes at dusk. Watc...
# 5   Forages on ground, while perching in weeds, or...
# 6   Does much foraging on ground, flipping leaves ...
# 7   Forages mostly on ground; sometimes will perch...
# 8   Opportunistic, quickly taking advantage of new...
# 9   Does much foraging on the ground, running and ...
# 10  Usually hunts by stealth, moving from perch to...
# 11  Forages actively in weeds, shrubs, and trees, ...
# 12  Captures insects mostly while walking and runn...
# 13  Typically forages in pairs, the two birds some...
# 14  Forages at all levels from ground up into shru...
# 15  Forages mostly by standing still or walking ve...
#
#                                                  diet  \
# 0   Mostly seeds, insects, berries. Diet is quite ...
# 1   Mostly small mammals. Eats many mice and other...
# 2   Omnivorous. Most of diet is vegetable matter (...
# 3   Varied, includes small mammals, birds, reptile...
# 4   Varied, mostly mammals and birds. Mammals make...
# 5   Mostly seeds, buds, berries. Almost all of die...
# 6   Mostly insects and berries. Especially in earl...
# 7   Seeds. Feeds almost entirely on seeds (99% of ...
# 8   Omnivorous. Seems to feed on practically anyth...
# 9   Mostly insects, berries, earthworms. In early ...
# 10  Mostly birds and small mammals. Feeds mainly o...
# 11  Mostly seeds, some insects. Diet is primarily ...
# 12  Mostly insects and berries. Annual diet is abo...
# 13  Omnivorous. May feed on practically anything, ...
# 14  Mostly seeds and insects. In breeding season f...
# 15  Highly variable and adaptable. Eats mostly fis...
#
#                                               nesting  \
# 0   Male sings to defend nesting territory, active...
# 1   Courtship involves both male and female bobbin...
# 2   Courtship may involve aerial chases; male may ...
# 3   In courtship, male and female soar in high cir...
# 4   May begin nesting very early in north (late wi...
# 5   Pairs may begin to form within flocks in winte...
# 6   Early in breeding season, male sings constantl...
# 7   In courtship, male flies up with noisy wingbea...
# 8   In courtship on ground or in tree, male faces ...
# 9   Males arrive before females on nesting grounds...
# 10  In courtship (and occasionally at other times)...
# 11  Nesting begins late in season in many areas, w...
# 12  Nesting begins early, by late winter in southe...
# 13  In courtship display, male soars, swoops, and ...
# 14  Male establishes territory in spring, defends ...
# 15  Breeds in colonies, often of this species alon...
#
#                                                images
# 0   [https://media.audubon.org/nas_birdapi_hero/h_...
# 1   [https://media.audubon.org/nas_birdapi_hero/we...
# 2   [https://media.audubon.org/nas_birdapi_hero/sf...
# 3   [https://media.audubon.org/nas_birdapi_hero/h_...
# 4   [https://media.audubon.org/nas_birdapi_hero/we...
# 5   [https://media.audubon.org/nas_birdapi_hero/h_...
# 6   [https://media.audubon.org/nas_birdapi_hero/we...
# 7   [https://media.audubon.org/nas_birdapi_hero/h_...
# 8   [https://media.audubon.org/nas_birdapi_hero/we...
# 9   [https://media.audubon.org/nas_birdapi_hero/we...
# 10  [https://media.audubon.org/nas_birdapi_hero/a1...
# 11  [https://media.audubon.org/nas_birdapi_hero/h_...
# 12  [https://media.audubon.org/nas_birdapi_hero/a1...
# 13  [https://media.audubon.org/nas_birdapi_hero/h_...
# 14  [https://media.audubon.org/nas_birdapi_hero/h_...
# 15  [https://media.audubon.org/nas_birdapi_hero/h_...
#
# [16 rows x 26 columns]

# %%
subset_toHeron.to_csv('subset_birds.csv', index=True)
